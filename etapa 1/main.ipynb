# %% [markdown]
# # Etapa 1 - Projeto Desenvolvedor 🚀

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("BrStats.csv", sep = ";")
# Out:
# C:\Users\aline\AppData\Local\Temp\ipykernel_6156\1085877892.py:1: DtypeWarning: Columns (2,3,4,5,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("BrStats.csv", sep = ";")

# %%
display(df)
# Out:
#         Ano  CDMunicipio Populacao PessoalOcupado PessoalAssalariado  \
# 0      2016      3509452     5.932            854                537
# 1      2016      3123601    27.505          5.680              4.778
# 2      2016      3552007     6.193            668                580
# 3      2016      3305604    21.279          3.087              2.669
# 4      2016      1717008     4.534            212                183
# ...     ...          ...       ...            ...                ...
# 33415  2021      2705408     7.171          463.0              436.0
# 33416  2021      1600105     9.265          428.0              383.0
# 33417  2019      2605459     3.061           2.21              1.773
# 33418  2020      1503002      7.07          538.0              514.0
# 33419  2021      3166709     8.725          852.0              773.0
#
#       VrSalarios      PIB  QtEmpresas  AreaPlantada_h  AreaColhida_h  ...  \
# ...
